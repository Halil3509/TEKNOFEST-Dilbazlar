# %%
import pandas as pd 
from tqdm import tqdm
import sys
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

# %%
data1 = pd.read_csv("Data\dysthymia_llm_filtered_en_yeni.csv")
data2 = pd.read_csv("Data\dysthymia_llm_filtered_en_yeni2.csv")
data3 = pd.read_csv("Data\dysthymia_llm_filtered_en_yeni3.csv")

data1
# Out:
#      Result                                               Text
# 0       yes  I've always been very hard on myself to be thi...
# 1       yes  I struggle a lot with motivation, to do someth...
# 2       yes  diagnosed with dysthymia a few months ago. psy...
# 3       yes  I keep cycling randomly through the same half ...
# 4       yes  I’ve been feeling actively bad for the past fe...
# ...     ...                                                ...
# 1531    yes  I have always had this habit of oversleeping d...
# 1532    yes  I have brain fog and my brain feels empty all ...
# 1533    yes  After years of feeling terrible about myself, ...
# 1534     no  The provided text does not describe the storie...
# 1535    yes  I'm stuck on two emotions: angry or sad. I don...
#
# [1536 rows x 2 columns]

# %%
data2
# Out:
#      Result                                               Text
# 0       yes  luckily so far dysthymia has not interfered in...
# 1        no  My copay for a therapist through my insurance ...
# 2       yes  I feel so fucking sick. I have a constant head...
# 3       yes  struggled with depression most of my adult lif...
# 4       yes  i still fucking hate myself. i have absolutely...
# ...     ...                                                ...
# 1696    yes  I just cant take it anymore. i have been depre...
# 1697    yes  I vacillate between letting others know I have...
# 1698    yes  Had a schedule after my recent diagnosis. Had ...
# 1699    yes  everything has this gray filter, metaphoricall...
# 1700    yes  I have this lowkey background sadness and chro...
#
# [1701 rows x 2 columns]

# %%
data1 = data1[data1["Result"]== "yes"]

data1
# Out:
#      Result                                               Text
# 0       yes  I've always been very hard on myself to be thi...
# 1       yes  I struggle a lot with motivation, to do someth...
# 2       yes  diagnosed with dysthymia a few months ago. psy...
# 3       yes  I keep cycling randomly through the same half ...
# 4       yes  I’ve been feeling actively bad for the past fe...
# ...     ...                                                ...
# 1530    yes  felt like I’ve been living in a real gray area...
# 1531    yes  I have always had this habit of oversleeping d...
# 1532    yes  I have brain fog and my brain feels empty all ...
# 1533    yes  After years of feeling terrible about myself, ...
# 1535    yes  I'm stuck on two emotions: angry or sad. I don...
#
# [1386 rows x 2 columns]

# %%
data2 = data2[data2["Result"]== "yes"]

data2
# Out:
#      Result                                               Text
# 0       yes  luckily so far dysthymia has not interfered in...
# 2       yes  I feel so fucking sick. I have a constant head...
# 3       yes  struggled with depression most of my adult lif...
# 4       yes  i still fucking hate myself. i have absolutely...
# 5       yes  I dread answering any questions like that and ...
# ...     ...                                                ...
# 1696    yes  I just cant take it anymore. i have been depre...
# 1697    yes  I vacillate between letting others know I have...
# 1698    yes  Had a schedule after my recent diagnosis. Had ...
# 1699    yes  everything has this gray filter, metaphoricall...
# 1700    yes  I have this lowkey background sadness and chro...
#
# [1513 rows x 2 columns]

# %%
data3 = data3[data3["Result"]== "yes"]

data3
# Out:
#      Result                                               Text
# 0       yes  The thought of having someone demanding attent...
# 1       yes  I'm only alive bc my attempts failed, I'm only...
# 2       yes  I have chronic treatment resistant depression,...
# 3       yes                                  I feel trapped :/
# 5       yes  I really have to force myself to do anything s...
# ...     ...                                                ...
# 1737    yes  my symptoms are worse than before, low confide...
# 1738    yes  It gets worse when they start losing interest ...
# 1739    yes                     I got diagnosed with Dysthymia
# 1740    yes  I can relate to a lot of symptoms but not all ...
# 1741    yes  I'm starting to think I should never feel bett...
#
# [1536 rows x 2 columns]

# %%
data = pd.concat([data1, data2,data3], ignore_index=True)

data
# Out:
#      Result                                               Text
# 0       yes  I've always been very hard on myself to be thi...
# 1       yes  I struggle a lot with motivation, to do someth...
# 2       yes  diagnosed with dysthymia a few months ago. psy...
# 3       yes  I keep cycling randomly through the same half ...
# 4       yes  I’ve been feeling actively bad for the past fe...
# ...     ...                                                ...
# 4430    yes  my symptoms are worse than before, low confide...
# 4431    yes  It gets worse when they start losing interest ...
# 4432    yes                     I got diagnosed with Dysthymia
# 4433    yes  I can relate to a lot of symptoms but not all ...
# 4434    yes  I'm starting to think I should never feel bett...
#
# [4435 rows x 2 columns]

# %%
pd.set_option('display.max_colwidth', None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4435 entries, 0 to 4434
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Result  4435 non-null   object
#  1   Text    4435 non-null   object
# dtypes: object(2)
# memory usage: 69.4+ KB

# %%
ex_data = pd.read_excel("Data\dysthymia_llm_filtered_en.xlsx")

ex_data
# Out:
#      Result                                               Text
# 0       yes  I am productive and motivated... ...fuck every...
# 1       yes  when I attempt to drive it almost doesn’t feel...
# 2        no                                   Hey everyone,...
# 3       yes  whenever i get the house to myself... it’s lik...
# 4       yes  I've been suicidal for the past 10 years and s...
# ...     ...                                                ...
# 1050    yes  can't really bring myself to do much. The last...
# 1051    yes  My moods seem to change like the weather. I ma...
# 1052    yes  I tend to feel really empty, or kinda sad actu...
# 1053    yes  I've read so many stories of people being unab...
# 1054    yes  I've been feeling stressed and on the brink of...
#
# [1055 rows x 2 columns]

# %%
# Filter the new DataFrame to remove rows with matching "Text" in the existing DataFrame
filtered_new_df = data[~data['Text'].isin(ex_data['Text'])]

# %%
filtered_new_df
# Out:
#      Result                                               Text
# 0       yes  I've always been very hard on myself to be thi...
# 1       yes  I struggle a lot with motivation, to do someth...
# 2       yes  diagnosed with dysthymia a few months ago. psy...
# 3       yes  I keep cycling randomly through the same half ...
# 4       yes  I’ve been feeling actively bad for the past fe...
# ...     ...                                                ...
# 4430    yes  my symptoms are worse than before, low confide...
# 4431    yes  It gets worse when they start losing interest ...
# 4432    yes                     I got diagnosed with Dysthymia
# 4433    yes  I can relate to a lot of symptoms but not all ...
# 4434    yes  I'm starting to think I should never feel bett...
#
# [3743 rows x 2 columns]

# %%
data = filtered_new_df[filtered_new_df['Text'].apply(lambda x: isinstance(x, str))]

# %%
from transformers import MarianMTModel, MarianTokenizer
import torch
from tqdm import tqdm  # Import tqdm for the progress bar

model_name = "Helsinki-NLP/opus-mt-tc-big-en-tr"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def batch_translate_text(texts, batch_size=8):
    translated_texts = []
    # Use tqdm to create a progress bar
    for i in tqdm(range(0, len(texts), batch_size), desc="Translating"):
        batch_texts = texts[i:i + batch_size]
        inputs = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True).to(device)
        translated = model.generate(**inputs)
        translated_batch = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
        translated_texts.extend(translated_batch)
    return translated_texts

# Example data
# data = pd.DataFrame({'Text': ['Text 1', 'Text 2', 'Text 3', ...]})
texts = data['Text'].tolist()
translated_texts = batch_translate_text(texts)

data['Translated_Text'] = translated_texts

data
# Out:
# vocab.json:   0%|          | 0.00/1.50M [00:00<?, ?B/s]
# c:\Users\AKAY\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\AKAY\.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-tc-big-en-tr. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
data.to_excel("distimi_last.xlsx", index=False)
